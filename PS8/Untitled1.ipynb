# %%
import matplotlib.pyplot as plt

# %%
n = [100,200,400,800]
std_dev = [0.0779462, 0.0544037, 0.0377157, 0.0259455]

# %%
plt.plot(n, std_dev, 'bo')
plt.xlabel('Number of values')
plt.ylabel('Standard Deviation of estimator')
plt.grid(True)
